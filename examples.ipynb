# %%
from graph_and_edge_objects_settings import Graph,Edge

# %%
vertices_2  = {"A","B","C","D","E","F"}
edges_2 = [Edge("A","B",weight=2),Edge("A","B",weight=3),Edge("A","B",weight=2),Edge("B","A",weight=2),Edge("B","A",weight=3),Edge("B","A",weight=2,frequency=2),Edge("B","C",weight=1),Edge("C","D",weight=4),Edge("D","E",weight=2),Edge("E","F",weight=5),Edge("F","A",weight=1),Edge("A","A")]
graph2 = Graph(vertices_2,edges_2,directed=True,multigraph=False,weighted=True)

graph2.print_adjacency_dict()
graph2.add_edge(Edge("B","D"))

print("\n\n\n")
graph2.print_adjacency_dict()

print(graph2.degree("A"))

graph2.get_adjacency_matrix()
graph2.print_matrix(graph2.adjacency_matrix)

graph2.get_n_step_walks(5)
graph2.print_matrix(graph2.n_step_walk_matrix)

graph2.get_cumulative_n_step_walks(5)
graph2.print_matrix(graph2.cumulative_n_step_walk_matrix)

print(graph2.check_connectivity())
# Out:
# A: {
# -B: weight: 2, frequency: 1
# }
#
# B: {
# -A: weight: 2, frequency: 1
# -C: weight: 1, frequency: 1
# }
#
# C: {
# -D: weight: 4, frequency: 1
# }
#
# D: {
# -E: weight: 2, frequency: 1
# }
#
# E: {
# -F: weight: 5, frequency: 1
# }
#
# F: {
# -A: weight: 1, frequency: 1
# }
#
#
#
#
#
# A: {
# -B: weight: 2, frequency: 1
# }
#
# B: {
# -A: weight: 2, frequency: 1
# -C: weight: 1, frequency: 1
# -D: weight: 1, frequency: 1
# }
#
# C: {
# -D: weight: 4, frequency: 1
# }
#
# D: {
# -E: weight: 2, frequency: 1
# }
#
# E: {
# -F: weight: 5, frequency: 1
# }
#
# F: {
# -A: weight: 1, frequency: 1
# }
#
# 3
# 0|A B C D E F
# A|0 1 0 0 0 0
# B|1 0 1 1 0 0
# C|0 0 0 1 0 0
# D|0 0 0 0 1 0
# E|0 0 0 0 0 1
# F|1 0 0 0 0 0
#
# 0|A B C D E F
# A|1 1 0 1 1 1
# B|2 1 1 1 1 1
# C|0 1 0 0 0 0
# D|1 0 1 1 0 0
# E|0 1 0 1 1 0
# F|1 0 1 1 1 1
#
# 0|A B C D E F
# A|3 3 2 4 3 2
# B|5 3 3 5 4 3
# C|1 1 0 1 1 1
# D|2 1 1 1 1 1
# E|2 2 1 2 1 1
# F|3 2 2 3 2 1
#
# True
